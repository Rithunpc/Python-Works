# %%
import pandas as pd
data = pd.read_excel('Oorjja.xlsx')
data
# Out:
#                           Timestamp              NAME  \
# 0    2021/07/27 2:47:35 PM GMT+5:30     Anjali Manuel
# 1    2021/07/27 2:48:44 PM GMT+5:30  Mukund Bhaskaran
# 2    2021/07/27 2:50:08 PM GMT+5:30         Akshaya R
# 3    2021/07/27 2:50:30 PM GMT+5:30           Anusree
# 4    2021/07/27 2:50:42 PM GMT+5:30       Aswathy A.B
# 5    2021/07/27 2:51:32 PM GMT+5:30              Rose
# 6    2021/07/27 2:54:33 PM GMT+5:30           Christy
# 7    2021/07/27 2:55:51 PM GMT+5:30      Vince Wilson
# 8   2022/05/26 10:12:24 AM GMT+5:30         Sona Babu
# 9   2022/05/26 10:13:54 AM GMT+5:30       Soul Joseph
# 10  2023/04/04 11:24:37 AM GMT+5:30       Liya Roslin
# 11  2023/04/04 11:25:15 AM GMT+5:30          Alfy N P
# 12  2023/04/04 11:25:32 AM GMT+5:30          ANJU P K
# 13  2023/04/04 11:28:59 AM GMT+5:30       Jiyamol Joy
# 14  2023/04/04 11:29:26 AM GMT+5:30        Rithun P C
# 15  2023/04/04 11:29:32 AM GMT+5:30   Akshara Vincent
# ...

# %%
data.head()
# Out:
#                         Timestamp              NAME               Place  \
# 0  2021/07/27 2:47:35 PM GMT+5:30     Anjali Manuel              Kannur
# 1  2021/07/27 2:48:44 PM GMT+5:30  Mukund Bhaskaran          Eranakulam
# 2  2021/07/27 2:50:08 PM GMT+5:30         Akshaya R  Thiruvananthapuram
# 3  2021/07/27 2:50:30 PM GMT+5:30           Anusree           Chalakudy
# 4  2021/07/27 2:50:42 PM GMT+5:30       Aswathy A.B              Vaikom
#
#   Designation  GENDER                 EDUCATION  Age  \
# 0     Student  FEMALE       Post graduation(PG)   25
# 1     Student    MALE  Graduation(Degree)(Bcom)   37
# 2     Student  FEMALE     12 (higher secondary)   22
# 3     Teacher  FEMALE       Post graduation(PG)   25
# 4     Student  FEMALE  Graduation(Degree)(Bcom)   21
#
#   Number of members in your family ? Size of your shirt?  \
# 0                                  4                   L
# 1                                  5                  XL
# ...

# %%
data.tail()
# Out:
#                           Timestamp             NAME  \
# 14  2023/04/04 11:29:26 AM GMT+5:30       Rithun P C
# 15  2023/04/04 11:29:32 AM GMT+5:30  Akshara Vincent
# 16  2023/04/04 11:29:46 AM GMT+5:30          Ajesh C
# 17  2023/04/04 11:31:27 AM GMT+5:30        Athira pv
# 18  2023/04/04 11:31:38 AM GMT+5:30   Remya Raghavan
#
#                                                 Place Designation  GENDER  \
# 14  POOLACHALIL (H),MEPPAYUR(P O), KOYLANDY(V),KOZ...     Student    MALE
# 15                                        thadikkadvu     Student  FEMALE
# 16                                          Alappuzha     Student    MALE
# 17                                           thrissur     Student  FEMALE
# 18                                        perumbavoor     Student  FEMALE
#
#                    EDUCATION  Age Number of members in your family ?  \
# 14  Graduation(Degree)(Bcom)   27         My families have 6 members
# ...

# %%
data.shape
# Out:
# (19, 15)

# %%
data.dtypes
# Out:
# Timestamp                                                            object
# NAME                                                                 object
# Place                                                                object
# Designation                                                          object
# GENDER                                                               object
# EDUCATION                                                            object
# Age                                                                   int64
# Number of members in your family ?                                   object
# Size of your shirt?                                                  object
# Number of knives at your home?                                       object
# Number of chairs in your home?                                       object
# Which is your favorite color                                         object
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'NAME', 'Place', 'Designation', 'GENDER', 'EDUCATION',
#        'Age', 'Number of members in your family ?', 'Size of your shirt?',
#        'Number of knives at your home?', 'Number of chairs in your home?',
#        'Which is your favorite color',
#        'How many liters of milk are being bought every day in your house?',
#        'Height in cm', 'Weight in kg'],
#       dtype='object')

# %%
data.head(3)
# Out:
#                         Timestamp              NAME               Place  \
# 0  2021/07/27 2:47:35 PM GMT+5:30     Anjali Manuel              Kannur
# 1  2021/07/27 2:48:44 PM GMT+5:30  Mukund Bhaskaran          Eranakulam
# 2  2021/07/27 2:50:08 PM GMT+5:30         Akshaya R  Thiruvananthapuram
#
#   Designation  GENDER                 EDUCATION  Age  \
# 0     Student  FEMALE       Post graduation(PG)   25
# 1     Student    MALE  Graduation(Degree)(Bcom)   37
# 2     Student  FEMALE     12 (higher secondary)   22
#
#   Number of members in your family ? Size of your shirt?  \
# 0                                  4                   L
# 1                                  5                  XL
# 2                       My Family- 3                  XL
#
#   Number of knives at your home? Number of chairs in your home?  \
# 0                              7                             15
# 1                              3                              9
# ...

# %%
data.tail(4)
# Out:
#                           Timestamp             NAME        Place Designation  \
# 15  2023/04/04 11:29:32 AM GMT+5:30  Akshara Vincent  thadikkadvu     Student
# 16  2023/04/04 11:29:46 AM GMT+5:30          Ajesh C    Alappuzha     Student
# 17  2023/04/04 11:31:27 AM GMT+5:30        Athira pv     thrissur     Student
# 18  2023/04/04 11:31:38 AM GMT+5:30   Remya Raghavan  perumbavoor     Student
#
#     GENDER                 EDUCATION  Age Number of members in your family ?  \
# 15  FEMALE  Graduation(Degree)(Bcom)   21                                  4
# 16    MALE  Graduation(Degree)(Bcom)   30                               Five
# 17  FEMALE  Graduation(Degree)(Bcom)   23                               four
# 18  FEMALE  Graduation(Degree)(Bcom)   23                                  5
#
#    Size of your shirt? Number of knives at your home?  \
# 15                  XL                              3
# 16                   S                            Two
# ...
